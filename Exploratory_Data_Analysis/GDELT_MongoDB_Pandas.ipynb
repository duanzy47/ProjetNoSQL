# %% [markdown]
# ***
#
# **GDELT MongoDB**
#
# ***
#
# Note: Syntax can be easily transitioned to Spark DataFrame.
#
# We will do create 2 MongoDB collections:
#
# - `gdelt_2019_mentions`: Events tables with Mentions tables inserted as a field of Events
# - `gdelt_2019_events`: GKG tables but with string pseudo-lists transformed to lists

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import pymongo as mb
plt.style.use('fivethirtyeight')
from pprint import pprint
from tqdm import tqdm

# %% [markdown]
# # 1. GDELT Data Preprocessing with Pandas
#
# **TODO in Spark with Scala**
#
# 1. gdelt_events:
#     - Checks on variable types
# 2. gdelt_mentions:
#     - Reduce DataFrame to 2 columns *GLOBALEVENTID* (for merge with gdelt_events) and *mentions* (the rest)
#     - Checks on variable types
#     - Create column for language of article / mention
# 3. gdelt_gkg:
#     - Transfomring columns with poorly formated lists into dictionnaries
#     - Checks on variable types

# %%
gdelt_events = pd.read_csv('test_local_gdelt_events.csv', index_col=0)
gdelt_mentions = pd.read_csv('test_local_gdelt_mentions.csv', index_col=0)
gdelt_gkg = pd.read_csv('test_local_gdelt_gkg.csv', index_col=0)
# Out:
# c:\anaconda\lib\site-packages\IPython\core\interactiveshell.py:2728: DtypeWarning: Columns (15) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
# c:\anaconda\lib\site-packages\IPython\core\interactiveshell.py:2728: DtypeWarning: Columns (23) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
try:
    gdelt_mentions = gdelt_mentions.drop(['MentionDocOriginalLanguage'], axis=1)
except:
    pass

# %% [markdown]
# ## 1.1. GDELT Mentions
#
# **Get Article Language**

# %%
def get_article_mention_language(translateInfo):
    if translateInfo=='':
        language = 'eng'
    else:
        language = translateInfo.split(';', 1)[0][-3:]
    return language

gdelt_mentions_processed = gdelt_mentions.copy()
gdelt_mentions_processed = gdelt_mentions_processed.fillna('')

gdelt_mentions_processed['MentionDocOriginalLanguage'] = \
                    gdelt_mentions_processed['MentionDocTranslationInfo'].apply(lambda x: get_article_mention_language(x))

# %%
gdelt_mentions_processed['MentionDocOriginalLanguage'].value_counts(True).head(20)
# Out:
# eng    0.776453
# spa    0.083250
# ara    0.045934
# fra    0.023721
# rus    0.013271
# por    0.012400
# deu    0.007500
# ita    0.004068
# ron    0.003158
# ell    0.002613
# tur    0.002483
# dan    0.002054
# ukr    0.002054
# swe    0.001807
# srp    0.001742
# urd    0.001495
# ind    0.001417
# pol    0.001378
# slv    0.001118
# ces    0.001027
# Name: MentionDocOriginalLanguage, dtype: float64

# %%
# %%time
# gdelt_mentions_processed_bis = gdelt_mentions_processed[['GLOBALEVENTID']]
# gdelt_mentions_processed_bis['mentions'] = gdelt_mentions_processed.drop('GLOBALEVENTID', axis=1).to_dict(orient='records')
# gdelt_mentions_processed_bis = gdelt_mentions_processed_bis.groupby('GLOBALEVENTID')['mentions'].apply(list)
# gdelt_mentions_processed_bis = gdelt_mentions_processed_bis.reset_index()
# gdelt_mentions_processed_bis.head()

# %%
print(gdelt_mentions.shape)
print(gdelt_mentions_processed.shape)
# Out:
# (76937, 16)
# (76937, 17)

# %%
gdelt_mentions_processed.GLOBALEVENTID.unique().shape[0] / gdelt_mentions_processed.shape[0]
# Out:
# 0.55388174740372

# %%
gdelt_mentions_processed.head()
# Out:
#    GLOBALEVENTID   EventTimeDate  MentionTimeDate  MentionType  \
# 0      410412347  20150218230000   20150218230000            1
# 1      410412348  20150218230000   20150218230000            1
# 2      410412349  20150218230000   20150218230000            1
# 3      410412350  20150218230000   20150218230000            1
# 4      410412351  20150218230000   20150218230000            1
#
#      MentionSourceName                                  MentionIdentifier  \
# 0  dailymaverick.co.za  http://www.dailymaverick.co.za/article/2015-02...
# 1       indiatimes.com  http://timesofindia.indiatimes.com/city/bengal...
# 2           voxy.co.nz  http://www.voxy.co.nz/entertainment/coast-new-...
# 3           voxy.co.nz  http://www.voxy.co.nz/entertainment/coast-new-...
# 4    eastidahonews.com  http://www.eastidahonews.com/2015/02/neil-patr...
#
#    SentenceID  Actor1CharOffset  Actor2CharOffset  ActionCharOffset  \
# 0          19                -1              4594              4634
# 1           2                -1               300               344
# 2           4                -1              1297              1232
# 3           4                -1              1298              1233
# 4           1                -1               103               122
#
#    InRawText  Confidence  MentionDocLen  MentionDocTone  \
# 0          1          50           6665       -4.477612
# 1          1          50           2541        2.078522
# 2          0          10           2576        7.517084
# 3          1          20           2576        7.517084
# 4          1         100           1432        0.000000
#
#   MentionDocTranslationInfo Extras MentionDocOriginalLanguage
# 0                                                         eng
# 1                                                         eng
# 2                                                         eng
# 3                                                         eng
# 4                                                         eng

# %% [markdown]
# ## 1.2. GDELT Events

# %%
gdelt_events_preprocessed = gdelt_events.copy()
gdelt_events_preprocessed['ActionGeo_CountryCode'] = gdelt_events_preprocessed['ActionGeo_CountryCode'].fillna('UNK')
gdelt_events_preprocessed = gdelt_events_preprocessed.fillna('')
# gdelt_events_preprocessed['mentions'] = np.empty((len(gdelt_events_preprocessed), 0)).tolist()
gdelt_events_preprocessed.head()
# Out:
#    GLOBALEVENTID   SQLDATE  MonthYear  Year  FractionDate Actor1Code  \
# 0      410412347  20140218     201402  2014     2014.1315
# 1      410412348  20140218     201402  2014     2014.1315
# 2      410412349  20140218     201402  2014     2014.1315
# 3      410412350  20140218     201402  2014     2014.1315
# 4      410412351  20140218     201402  2014     2014.1315
#
#   Actor1Name Actor1CountryCode Actor1KnownGroupCode Actor1EthnicCode  \
# 0
# 1
# 2
# 3
# 4
#
#                          ...                         ActionGeo_Type  \
# 0                        ...                                      4
# 1                        ...                                      4
# 2                        ...                                      4
# 3                        ...                                      1
# 4                        ...                                      2
#
#                      ActionGeo_FullName ActionGeo_CountryCode  \
# 0  Waterkloof, Free State, South Africa                    SF
# 1           Bengaluru, Karnataka, India                    IN
# 2   Great Southern, Victoria, Australia                    AS
# 3                           New Zealand                    NZ
# 4                  Idaho, United States                    US
#
#   ActionGeo_ADM1Code ActionGeo_ADM2Code ActionGeo_Lat ActionGeo_Long  \
# 0               SF03              77359      -30.3098        25.2971
# 1               IN19              70159       12.9833        77.5833
# 2               AS07               5387      -36.0667        146.483
# 3                 NZ                              -41            174
# 4               USID                          44.2394        -114.51
#
#   ActionGeo_FeatureID       DATEADDED  \
# 0            -1299321  20150218230000
# 1            -2090174  20150218230000
# 2            -1576477  20150218230000
# 3                  NZ  20150218230000
# 4                  ID  20150218230000
#
#                                            SOURCEURL
# 0  http://www.dailymaverick.co.za/article/2015-02...
# 1  http://timesofindia.indiatimes.com/city/bengal...
# 2  http://www.voxy.co.nz/entertainment/coast-new-...
# 3  http://www.voxy.co.nz/entertainment/coast-new-...
# 4  http://www.eastidahonews.com/2015/02/neil-patr...
#
# [5 rows x 61 columns]

# %% [markdown]
# ## 1.3. GDELT GKG
#
# Columns to format from string to list :
#
# - AllNames (;)
# - Amounts (;)
# - Counts (;)
# - GCAM (,)
# - **Locations** (;)
# - Organizations (;)
# - **Persons** (;)
# - Quotations (;)
# - Related Images
# - **Themes** (;)
# - V2Counts (;)
# - V2Locations (;)
# - V2Organizations (;)
# - V2Persons (;)
# - V2Themes (;)
# - **V2Tone** (,)

# %% [markdown]
# In particular:
#
# - **V2TONE**: (comma-delimited floating point numbers) This field contains a comma-delimited
# list of six core emotional dimensions, described in more detail below. Each is recorded as a
# single precision floating point number. This field is nearly identical in format and population as
# the corresponding field in the GKG 1.0 format with the sole exception of adding the single new
# WordCount variable at the end.
#
#     1. **Tone**. (floating point number) This is the average “tone” of the document as a whole.
# The score ranges from -100 (extremely negative) to +100 (extremely positive). Common
# values range between -10 and +10, with 0 indicating neutral. This is calculated as
# Positive Score minus Negative Score.
#     2. **Positive Score**. (floating point number) This is the percentage of all words in the article
# that were found to have a positive emotional connotation. Ranges from 0 to +100.
#     3. **Negative Score**
#     4. **Polarity**. (floating point number) This is the percentage of words that had matches in
# the tonal dictionary as an indicator of how emotionally polarized or charged the text is.
# If Polarity is high, but Tone is neutral, this suggests the text was highly emotionally
# charged, but had roughly equivalent numbers of positively and negatively charged
# emotional words.
#     5. **Activity Reference Density**. (floating point number) This is the percentage of words
# that were active words offering a very basic proxy of the overall “activeness” of the text
# compared with a clinically descriptive text.
#     6. **Self/Group Reference Density**. (floating point number) This is the percentage of all
# words in the article that are pronouns, capturing a combination of self-references and
# group-based discourse. News media material tends to have very low densities of such
# language, but this can be used to distinguish certain classes of news media and certain
# contexts.

# %% [markdown]
# - **Locations**: In cases where it is necessary to collapse by feature, the Geo_FeatureID column should be used, rather than the Geo_Fullname column. This is because the Geo_Fullname column captures the name of the location as expressed in the text and thus reflects differences in transliteration, alternative spellings, and alternative names for the same location. For example, Mecca is often spelled Makkah, while Jeddah is commonly spelled Jiddah or Jaddah. The Geo_Fullname column will reflect each of these different spellings, while the Geo_FeatureID column will resolve them all to the same unique GNS or GNIS feature identification number.
#
#     1. **Location Type**
#     2. **Location Fullname**
#     3. **Location Country Code**
#     4. **Location ADM1Code**
#     5. **Location Latitude**
#     6. **Location Longitude**
#     7. **Location FeatureID** (text OR signed integer). This is the numeric GNS or GNIS FeatureID for this location OR a textual country or ADM1 code).
#
# Example:
# ```python
# ['4',
#  'Budapest, Budapest, Hungary',
#  'RS',
#  'HU05',
#  '47.5',
#  '19.0833',
#  '-850553']
# ```

# %%
test = 'TERROR;REBELS;TAX_ETHNICITY;TAX_ETHNICITY_UKRAINE'
test = test.split(';')
test
# Out:
# ['TERROR', 'REBELS', 'TAX_ETHNICITY', 'TAX_ETHNICITY_UKRAINE']

# %%
gdelt_gkg_preprocessed = gdelt_gkg.fillna('')

# %%
gdelt_gkg_preprocessed.columns
# Out:
# Index(['GKGRECORDID', 'DATE', 'SourceCollectionIdentifier', 'SourceCommonName',
#        'DocumentIdentifier', 'Counts', 'V2Counts', 'Themes', 'V2Themes',
#        'Locations', 'V2Locations', 'Persons', 'V2Persons', 'Organizations',
#        'V2Organizations', 'V2Tone', 'Dates', 'GCAM', 'SharingImage',
#        'RelatedImages', 'SocialImageEmbeds', 'SocialVideoEmbeds', 'Quotations',
#        'AllNames', 'Amounts', 'TranslationInfo', 'Extras'],
#       dtype='object')

# %%
# %%time
split_with_semicolon = ['AllNames', 'Amounts', 'Counts', 'Locations',
                        'Organizations', 'Persons', 'Quotations',
                        'RelatedImages', 'Themes', 'V2Counts',
                        'V2Locations', 'V2Organizations', 'V2Persons',
                        'V2Themes']

split_with_comma = ['GCAM', 'V2Tone']

gdelt_gkg_preprocessed[split_with_semicolon] = gdelt_gkg_preprocessed[split_with_semicolon].applymap(lambda x: x.split(';'))
gdelt_gkg_preprocessed[split_with_comma] = gdelt_gkg_preprocessed[split_with_comma].applymap(lambda x: x.split(','))
# Out:
# Wall time: 6.89 s

# %%
# def preprocess_gdelt_gkg_rows(row):
#     """ AAA """
#     # Split String Lists
#     split_with_semicolon = ['AllNames', 'Amounts', 'Counts', 'Locations',
#                             'Organizations', 'Persons', 'Quotations',
#                             'RelatedImages', 'Themes', 'V2Counts',
#                             'V2Locations', 'V2Organizations', 'V2Persons',
#                             'V2Themes']
    
#     split_with_comma = ['GCAM', 'V2Tone']
    
#     # General Splits
#     for key_name in split_with_semicolon:
#         # Transform string into list
#         row[key_name] = row[key_name].split(';')
        
#         # Remove elements with empty strings
#         row[key_name] = [el for el in row[key_name] if el != '']
    
#     for key_name in split_with_comma:
#         # Transform string into list
#         row[key_name] = row[key_name].split(',')
        
#         # Remove elements with empty strings
#         row[key_name] = [el for el in row[key_name] if el != '']
    
#     return row

def preprocess_gdelt_gkg_tone(x):
    res = dict()
    res['tone'] = float(x[0])
    res['positive_score'] = x[1]
    res['negative_score'] = x[2]
    res['polarity'] = x[3]
    res['activity_reference_density'] = x[4]
    res['group_reference_density'] = x[5]
    return res

def preprocess_gdelt_gkg_location(x):
    res_list = []
    # print(x)
    if len(x) == 0:
        return []
        
    for location in x:
        if location != '':
            # print(location)
            x_split = location.split('#')
            # print(location, x_split)
            res = dict()
            res['type'] = x_split[0]
            res['full_name'] = x_split[1]
            res['country_code'] = x_split[2]
            res['adm1_code'] = x_split[3]
            res['latitude'] = x_split[4]
            res['longitude'] = x_split[5]
            res['featureID'] = x_split[6]
            res_list.append(res)
        
    return res_list

def preprocess_gdelt_themes(x):
    res = list(filter(lambda el: el != '', x))
    return res

# %%
# %%time
gdelt_gkg_preprocessed['V2Tone'] = gdelt_gkg_preprocessed['V2Tone'].apply(lambda x: preprocess_gdelt_gkg_tone(x))
gdelt_gkg_preprocessed['Locations'] = gdelt_gkg_preprocessed['Locations'].apply(lambda x: preprocess_gdelt_gkg_location(x))
# Out:
# Wall time: 242 ms

# %%
gdelt_gkg_preprocessed['Themes'] = gdelt_gkg_preprocessed['Themes'].apply(lambda x: preprocess_gdelt_themes(x))

# %%
pprint(gdelt_gkg_preprocessed[['GKGRECORDID', 'Locations', 'AllNames', 'Themes', 'V2Tone']].transpose().iloc[:,0].to_dict())
# Out:
# {'AllNames': ['Channel One,628',
#               'Channel One,755',
#               'Channel One,1449',
#               'Channel One,1672',
#               'Gen Aleksandr Lentsov,1994',
#               'Eduard Basuryn,2123',
#               'Ukrainian President Petro Poroshenko,2410',
#               'Sergey Mikheyev,2552',
#               'Hungarian Prime Minister Viktor Orban,2877',
#               'Deputy Prime Minister Arkadiy Dvorkovich,3603',
#               'Deputy Prime Minister Dvorkovich,3985',
#               'Channel One,4835'],
#  'GKGRECORDID': '20150218230000-0',
#  'Locations': [{'adm1_code': 'HU05',
#                 'country_code': 'RS',
#                 'featureID': '-850553',
#                 'full_name': 'Budapest, Budapest, Hungary',
#                 'latitude': '47.5',
#                 'longitude': '19.0833',
#                 'type': '4'},
#                {'adm1_code': 'RS25',
#                 'country_code': 'RS',
#                 'featureID': '139814',
#                 'full_name': "Ogarevo, Kaluzhskaya Oblast', Russia",
#                 'latitude': '55.2031',
#                 'longitude': '35.8328',
#                 'type': '4'},
#                {'adm1_code': 'HU',
#                 'country_code': 'RS',
#                 'featureID': 'HU',
#                 'full_name': 'Hungary',
#                 'latitude': '47',
#                 'longitude': '20',
#                 'type': '1'},
#                {'adm1_code': 'RS55',
#                 'country_code': 'RS',
#                 'featureID': '-2993111',
#                 'full_name': "Rossiya, Orenburgskaya Oblast', Russia",
#                 'latitude': '52.4',
#                 'longitude': '54.9833',
#                 'type': '4'},
#                {'adm1_code': 'UP25',
#                 'country_code': 'RS',
#                 'featureID': '-1046268',
#                 'full_name': "Maydan, Zakarpats'ka Oblast', Ukraine",
#                 'latitude': '48.6031',
#                 'longitude': '23.4741',
#                 'type': '4'},
#                {'adm1_code': 'UP',
#                 'country_code': 'RS',
#                 'featureID': 'UP',
#                 'full_name': 'Ukraine',
#                 'latitude': '49',
#                 'longitude': '32',
#                 'type': '1'},
#                {'adm1_code': 'RS',
#                 'country_code': 'RS',
#                 'featureID': 'RS',
#                 'full_name': 'Russia',
#                 'latitude': '60',
#                 'longitude': '100',
#                 'type': '1'},
#                {'adm1_code': 'UP14',
#                 'country_code': 'RS',
#                 'featureID': '-1045160',
#                 'full_name': "Luhansk, Luhans'ka Oblast', Ukraine",
#                 'latitude': '48.567',
#                 'longitude': '39.3171',
#                 'type': '4'},
#                {'adm1_code': 'RS59',
#                 'country_code': 'RS',
#                 'featureID': '11462001',
#                 'full_name': 'Novorossiya, Primorskiy Kray, Russia',
#                 'latitude': '43.3427',
#                 'longitude': '132.556',
#                 'type': '4'}],
#  'Themes': ['TERROR',
#             'REBELS',
#             'TAX_ETHNICITY',
#             'TAX_ETHNICITY_UKRAINIAN',
#             'TAX_WORLDLANGUAGES',
#             'TAX_WORLDLANGUAGES_UKRAINIAN',
#             'LEADER',
#             'TAX_FNCACT',
#             'TAX_FNCACT_PRESIDENT',
#             'TAX_FNCACT_TROOPS',
#             'TAX_FNCACT_AUTHORITIES',
#             'TAX_ETHNICITY_RUSSIAN',
#             'TAX_WORLDLANGUAGES_RUSSIAN',
#             'MEDIA_MSM',
#             'TAX_WORLDLANGUAGES_RUSSIA',
#             'MANMADE_DISASTER_IMPLIED',
#             'TAX_WORLDFISH',
#             'TAX_WORLDFISH_TOP',
#             'TAX_FNCACT_OFFICIAL',
#             'TAX_FNCACT_CORRESPONDENT',
#             'MILITARY',
#             'TAX_FNCACT_SERVICEMEN',
#             'ARREST',
#             'TAX_MILITARY_TITLE',
#             'TAX_MILITARY_TITLE_SOLDIERS',
#             'TAX_FNCACT_SOLDIERS',
#             'GENERAL_HEALTH',
#             'MEDICAL',
#             'TAX_FNCACT_WOMEN',
#             'TAX_FNCACT_CHILDREN',
#             'KILL',
#             'TAX_FNCACT_DEPUTY',
#             'TAX_FNCACT_ANALYST',
#             'TAX_ETHNICITY_UKRAINIANS',
#             'TAX_WORLDLANGUAGES_UKRAINIANS',
#             'TAX_ETHNICITY_HUNGARIAN',
#             'TAX_WORLDLANGUAGES_HUNGARIAN',
#             'TAX_FNCACT_MINISTER',
#             'TAX_FNCACT_PRIME_MINISTER',
#             'TAX_FNCACT_MINERS',
#             'TAX_FNCACT_DRIVERS',
#             'GENERAL_GOVERNMENT',
#             'PUBLIC_TRANSPORT',
#             'ARMEDCONFLICT',
#             'REBELLION',
#             'TAX_FNCACT_PRESENTER',
#             'CORRUPTION',
#             'SELF_IDENTIFIED_HUMAN_RIGHTS',
#             'FREESPEECH',
#             'POLITICAL_PRISONER',
#             'PROTEST',
#             'MOVEMENT_GENERAL'],
#  'V2Tone': {'activity_reference_density': '21.2566844919786',
#             'group_reference_density': '0.53475935828877',
#             'negative_score': '7.48663101604278',
#             'polarity': '9.62566844919786',
#             'positive_score': '2.13903743315508',
#             'tone': -5.3475935828877}}

# %% [markdown]
# # 2. Analyzing GDELT with MongoDB

# %% [markdown]
# ## 2.1. Bulk Insert Data into MongoDB
#
# **(a) MongoDB Client Server**

# %%
LOCAL_HOST_SERVER = 'localhost:27017'
mongo_client = mb.MongoClient(LOCAL_HOST_SERVER)

# %%
msbd_database = mongo_client['MSBD_2019_2020']

# %%
mb_gdelt_main = msbd_database['mb_gdelt_main']
mb_gdelt_gkg = msbd_database['gdelt_gkg']

try:
    _ = mb_gdelt_main.drop()
    print('Collection dropped.')
except:
    print('Collection already dropped.')
    
try:
    _ = mb_gdelt_gkg.drop()
    print('Collection dropped.')
except:
    print('Collection already dropped.')
    
mb_gdelt_mentions = msbd_database['mb_gdelt_main']
mb_gdelt_gkg = msbd_database['gdelt_gkg']
# Out:
# Collection dropped.
# Collection dropped.

# %%
print(msbd_database.list_collection_names())
# Out:
# ['gdelt_mentions_events', 'enron_emails']

# %% [markdown]
# **(b) Insert GDELT Events into MongoDB**

# %%
# %%time
pandas_to_mongo_events_data = gdelt_events_preprocessed.copy()
# pandas_to_mongo_events_data = pandas_to_mongo_events_data.rename(columns={'GLOBALEVENTID': '_id'})
pandas_to_mongo_events_data['_id'] = pandas_to_mongo_events_data['GLOBALEVENTID'].copy()
pandas_to_mongo_events_data = pandas_to_mongo_events_data.to_dict('records')
# Out:
# Wall time: 2.25 s

# %%
# %%time
_ = mb_gdelt_main.insert_many(pandas_to_mongo_events_data)
# Out:
# Wall time: 2.33 s

# %%
print(mb_gdelt_main.count_documents(filter={}))
# Out:
# 29319

# %% [markdown]
# **(c) Insert GDELT GKG into MongoDB**
#
# `GKGRECORDID` doesn't work there are duplicate ids.

# %%
# %%time
pandas_to_mongo_data_gkg = gdelt_gkg_preprocessed.copy()
# pandas_to_mongo_data_gkg = pandas_to_mongo_data_gkg.rename(columns={'GKGRECORDID': '_id'})
pandas_to_mongo_data_gkg = pandas_to_mongo_data_gkg.to_dict('records')
# Out:
# Wall time: 1.52 s

# %%
# %%time
_ = mb_gdelt_gkg.insert_many(pandas_to_mongo_data_gkg)
# Out:
# Wall time: 41.9 s

# %%
# for document in pandas_to_mongo_data_gkg:
#     _ = mb_gdelt_gkg.insert_one(document)

# %%
# pprint(pandas_to_mongo_data_gkg[0])

# %%
print(mb_gdelt_gkg.count_documents(filter={}))
# Out:
# 36478

# %%
# gdelt_events_preprocessed[gdelt_events_preprocessed['GLOBALEVENTID']==410412359]['mentions'].tolist()

# %%
# pprint(mb_gdelt_mentions.find_one({}))

# %%
# pprint(mb_gdelt_gkg.find_one({})['V2Tone'])

# %% [markdown]
# **(d) Update GDELT Events with GDELT Mentions**

# %%
pprint(mb_gdelt_main.find_one(filter={'_id': 410412374}))
# Out:
# {'ActionGeo_ADM1Code': 'IZ',
#  'ActionGeo_ADM2Code': '',
#  'ActionGeo_CountryCode': 'IZ',
#  'ActionGeo_FeatureID': 'IZ',
#  'ActionGeo_FullName': 'Iraq',
#  'ActionGeo_Lat': 33.0,
#  'ActionGeo_Long': 44.0,
#  'ActionGeo_Type': 1,
#  'Actor1Code': 'IRQ',
#  'Actor1CountryCode': 'IRQ',
#  'Actor1EthnicCode': '',
#  'Actor1Geo_ADM1Code': 'IZ',
#  'Actor1Geo_ADM2Code': '',
#  'Actor1Geo_CountryCode': 'IZ',
#  'Actor1Geo_FeatureID': 'IZ',
#  'Actor1Geo_FullName': 'Iraq',
#  'Actor1Geo_Lat': 33.0,
#  'Actor1Geo_Long': 44.0,
#  'Actor1Geo_Type': 1,
#  'Actor1KnownGroupCode': '',
#  'Actor1Name': 'IRAQ',
#  'Actor1Religion1Code': '',
#  'Actor1Religion2Code': '',
#  'Actor1Type1Code': '',
#  'Actor1Type2Code': '',
#  'Actor1Type3Code': '',
#  'Actor2Code': 'USA',
#  'Actor2CountryCode': 'USA',
#  'Actor2EthnicCode': '',
#  'Actor2Geo_ADM1Code': 'USIL',
#  'Actor2Geo_ADM2Code': 'IL031',
#  'Actor2Geo_CountryCode': 'US',
#  'Actor2Geo_FeatureID': '423587',
#  'Actor2Geo_FullName': 'Chicago, Illinois, United States',
#  'Actor2Geo_Lat': 41.85,
#  'Actor2Geo_Long': -87.6501,
#  'Actor2Geo_Type': 3,
#  'Actor2KnownGroupCode': '',
#  'Actor2Name': 'UNITED STATES',
#  'Actor2Religion1Code': '',
#  'Actor2Religion2Code': '',
#  'Actor2Type1Code': '',
#  'Actor2Type2Code': '',
#  'Actor2Type3Code': '',
#  'AvgTone': -1.1100376099597902,
#  'DATEADDED': 20150218230000,
#  'EventBaseCode': 43,
#  'EventCode': 43,
#  'EventRootCode': 4,
#  'FractionDate': 2014.1315,
#  'GLOBALEVENTID': 410412374,
#  'GoldsteinScale': 2.8,
#  'IsRootEvent': 0,
#  'MonthYear': 201402,
#  'NumArticles': 4,
#  'NumMentions': 4,
#  'NumSources': 3,
#  'QuadClass': 1,
#  'SOURCEURL': 'http://hosted2.ap.org/APDEFAULT/89ae8247abe8493fae24405546e9a1aa/Article_2015-02-18-US--GOP%202016-Bush%20Foreign%20Policy/id-73efbb63762c409f88ee7116da2a3e66',
#  'SQLDATE': 20140218,
#  'Year': 2014,
#  '_id': 410412374}

# %%
gdelt_mentions_processed[gdelt_mentions_processed.GLOBALEVENTID==410412374]
# Out:
#        GLOBALEVENTID   EventTimeDate  MentionTimeDate  MentionType  \
# 60         410412374  20150218230000   20150218230000            1
# 61         410412374  20150218230000   20150218230000            1
# 62         410412374  20150218230000   20150218230000            1
# 63         410412374  20150218230000   20150218230000            1
# 8508       410412374  20150218230000   20150218231500            1
# 8509       410412374  20150218230000   20150218231500            1
# 17376      410412374  20150218230000   20150218233000            1
# 17377      410412374  20150218230000   20150218233000            1
# 17378      410412374  20150218230000   20150218233000            1
# 17379      410412374  20150218230000   20150218233000            1
# 17380      410412374  20150218230000   20150218233000            1
# 17381      410412374  20150218230000   20150218233000            1
# 17382      410412374  20150218230000   20150218233000            1
# 27061      410412374  20150218230000   20150218234500            1
# 27062      410412374  20150218230000   20150218234500            1
# 27063      410412374  20150218230000   20150218234500            1
# 27064      410412374  20150218230000   20150218234500            1
# 27065      410412374  20150218230000   20150218234500            1
#
#             MentionSourceName  \
# 60                     ap.org
# 61       stamfordadvocate.com
# 62                 sacbee.com
# 63                     ap.org
# 8508               newser.com
# 8509         bostonherald.com
# 17376             roanoke.com
# 17377     billingsgazette.com
# 17378             kdhnews.com
# 17379              tucson.com
# 17380             cnsnews.com
# 17381        theworldlink.com
# 17382       newsradioklbj.com
# 27061      timesfreepress.com
# 27062            chippewa.com
# 27063   moultonadvertiser.com
# 27064            thetandd.com
# 27065  dailyjournalonline.com
#
#                                        MentionIdentifier  SentenceID  \
# 60     http://hosted2.ap.org/APDEFAULT/89ae8247abe849...          12
# 61     http://www.stamfordadvocate.com/news/politics/...          13
# 62     http://www.sacbee.com/news/politics-government...          13
# 63     http://hosted2.ap.org/APDEFAULT/3d281c11a96b4a...          12
# 8508   http://www.newser.com/article/73efbb63762c409f...          13
# 8509   http://www.bostonherald.com/news_opinion/natio...          13
# 17376  http://www.roanoke.com/news/politics/wire/jeb-...          15
# 17377  http://billingsgazette.com/news/national/elect...          13
# 17378  http://kdhnews.com/news/politics/jeb-bush-us-m...          15
# 17379  http://tucson.com/news/national/govt-and-polit...          13
# 17380  http://cnsnews.com/news/article/jeb-bush-us-mu...          13
# 17381  http://theworldlink.com/news/national/govt-and...          13
# 17382  http://www.newsradioklbj.com/news/politics/top...          13
# 27061  http://www.timesfreepress.com/news/breakingnew...          15
# 27062  http://chippewa.com/news/national/govt-and-pol...          13
# 27063  http://www.moultonadvertiser.com/news/national...          16
# 27064  http://thetandd.com/news/national/government-a...          13
# 27065  http://dailyjournalonline.com/news/politics/je...          13
#
#        Actor1CharOffset  Actor2CharOffset  ActionCharOffset  InRawText  \
# 60                 2833              2800              2821          0
# 61                 2841              2808              2829          0
# 62                 2817              2784              2805          0
# 63                 2833              2800              2821          0
# 8508               2638              2605              2626          0
# 8509               2838              2805              2826          0
# 17376              3819              3786              3807          0
# 17377              2841              2808              2829          0
# 17378              3819              3786              3807          0
# 17379              2841              2808              2829          0
# 17380              2841              2808              2829          0
# 17381              2841              2808              2829          0
# 17382              2841              2808              2829          0
# 27061              3635              3602              3623          0
# 27062              2841              2808              2829          0
# 27063              4323              4290              4311          0
# 27064              2841              2808              2829          0
# 27065              2841              2808              2829          0
#
#        Confidence  MentionDocLen  MentionDocTone MentionDocTranslationInfo  \
# 60             10           5143       -1.052632
# 61             10           5037       -1.180638
# 62             10           5670       -1.154250
# 63             10           5143       -1.052632
# 8508           10           4789       -1.354680
# 8509           10           5030       -1.182033
# 17376          10           6078       -1.188119
# 17377          10           5037       -1.180638
# 17378          10           6080       -1.188119
# 17379          10           5037       -1.180638
# 17380          10           5055       -1.180638
# 17381          10           5037       -1.180638
# 17382          10           5055       -1.180638
# 27061          10           5813       -1.035197
# 27062          10           5037       -1.180638
# 27063          10           6596       -1.187215
# 27064          10           5037       -1.180638
# 27065          10           5037       -1.180638
#
#       Extras MentionDocOriginalLanguage
# 60                                  eng
# 61                                  eng
# 62                                  eng
# 63                                  eng
# 8508                                eng
# 8509                                eng
# 17376                               eng
# 17377                               eng
# 17378                               eng
# 17379                               eng
# 17380                               eng
# 17381                               eng
# 17382                               eng
# 27061                               eng
# 27062                               eng
# 27063                               eng
# 27064                               eng
# 27065                               eng

# %%
# %%time
batch = gdelt_mentions_processed[gdelt_mentions_processed.GLOBALEVENTID==410412374].copy()
batch_1 = batch.iloc[:6,:].copy()
batch_2 = batch.iloc[6:,:].copy()

pandas_to_mongo_batch_1 = batch_1[['GLOBALEVENTID']].copy()
pandas_to_mongo_batch_1['MENTIONS'] = batch_1.drop('GLOBALEVENTID', axis=1).to_dict('records')
pandas_to_mongo_batch_1 = pandas_to_mongo_batch_1.groupby('GLOBALEVENTID')['MENTIONS'].apply(list)
pandas_to_mongo_batch_1 = pandas_to_mongo_batch_1.reset_index()
# pandas_to_mongo_batch_1_records = pandas_to_mongo_batch_1.to_dict('records')

pandas_to_mongo_batch_2 = batch_2[['GLOBALEVENTID']].copy()
pandas_to_mongo_batch_2['MENTIONS'] = batch_2.drop('GLOBALEVENTID', axis=1).to_dict('records')
pandas_to_mongo_batch_2 = pandas_to_mongo_batch_2.groupby('GLOBALEVENTID')['MENTIONS'].apply(list)
pandas_to_mongo_batch_2 = pandas_to_mongo_batch_2.reset_index()
# pandas_to_mongo_batch_2_records = pandas_to_mongo_batch_2.to_dict('records')
# Out:
# Wall time: 23.9 ms

# %%
pandas_to_mongo_batch_1
# Out:
#    GLOBALEVENTID                                           MENTIONS
# 0      410412374  [{'EventTimeDate': 20150218230000, 'MentionTim...

# %%
pandas_to_mongo_batch_2
# Out:
#    GLOBALEVENTID                                           MENTIONS
# 0      410412374  [{'EventTimeDate': 20150218230000, 'MentionTim...

# %%
# pprint(pandas_to_mongo_batch_1_records[0])

# %%
# pprint(pandas_to_mongo_batch_2_records[0])

# %%
# %%time
for _, row in pandas_to_mongo_batch_1.iterrows():
    _ = mb_gdelt_main.update_many({'GLOBALEVENTID': row['GLOBALEVENTID']},
                                 {'$push': {'MENTIONS': {'$each': row['MENTIONS']}}},
                                 upsert=True)
    break
# Out:
# Wall time: 56.8 ms

# %%
for _, row in pandas_to_mongo_batch_2.iterrows():
    _ = mb_gdelt_main.update_many({'GLOBALEVENTID': row['GLOBALEVENTID']},
                                 {'$push': {'MENTIONS': {'$each': row['MENTIONS']}}},
                                 upsert=True)
    break

# %%
pprint(mb_gdelt_main.find_one(filter={'_id': 410412374}))
# Out:
# {'ActionGeo_ADM1Code': 'IZ',
#  'ActionGeo_ADM2Code': '',
#  'ActionGeo_CountryCode': 'IZ',
#  'ActionGeo_FeatureID': 'IZ',
#  'ActionGeo_FullName': 'Iraq',
#  'ActionGeo_Lat': 33.0,
#  'ActionGeo_Long': 44.0,
#  'ActionGeo_Type': 1,
#  'Actor1Code': 'IRQ',
#  'Actor1CountryCode': 'IRQ',
#  'Actor1EthnicCode': '',
#  'Actor1Geo_ADM1Code': 'IZ',
#  'Actor1Geo_ADM2Code': '',
#  'Actor1Geo_CountryCode': 'IZ',
#  'Actor1Geo_FeatureID': 'IZ',
#  'Actor1Geo_FullName': 'Iraq',
#  'Actor1Geo_Lat': 33.0,
#  'Actor1Geo_Long': 44.0,
#  'Actor1Geo_Type': 1,
#  'Actor1KnownGroupCode': '',
#  'Actor1Name': 'IRAQ',
#  'Actor1Religion1Code': '',
#  'Actor1Religion2Code': '',
#  'Actor1Type1Code': '',
#  'Actor1Type2Code': '',
#  'Actor1Type3Code': '',
#  'Actor2Code': 'USA',
#  'Actor2CountryCode': 'USA',
#  'Actor2EthnicCode': '',
#  'Actor2Geo_ADM1Code': 'USIL',
#  'Actor2Geo_ADM2Code': 'IL031',
#  'Actor2Geo_CountryCode': 'US',
#  'Actor2Geo_FeatureID': '423587',
#  'Actor2Geo_FullName': 'Chicago, Illinois, United States',
#  'Actor2Geo_Lat': 41.85,
#  'Actor2Geo_Long': -87.6501,
#  'Actor2Geo_Type': 3,
#  'Actor2KnownGroupCode': '',
#  'Actor2Name': 'UNITED STATES',
#  'Actor2Religion1Code': '',
#  'Actor2Religion2Code': '',
#  'Actor2Type1Code': '',
#  'Actor2Type2Code': '',
#  'Actor2Type3Code': '',
#  'AvgTone': -1.1100376099597902,
#  'DATEADDED': 20150218230000,
#  'EventBaseCode': 43,
#  'EventCode': 43,
#  'EventRootCode': 4,
#  'FractionDate': 2014.1315,
#  'GLOBALEVENTID': 410412374,
#  'GoldsteinScale': 2.8,
#  'IsRootEvent': 0,
#  'MENTIONS': [{'ActionCharOffset': 2821,
#                'Actor1CharOffset': 2833,
#                'Actor2CharOffset': 2800,
#                'Confidence': 10,
#                'EventTimeDate': 20150218230000,
#                'Extras': '',
#                'InRawText': 0,
#                'MentionDocLen': 5143,
#                'MentionDocOriginalLanguage': 'eng',
#                'MentionDocTone': -1.05263157894737,
#                'MentionDocTranslationInfo': '',
#                'MentionIdentifier': 'http://hosted2.ap.org/APDEFAULT/89ae8247abe8493fae24405546e9a1aa/Article_2015-02-18-US--GOP%202016-Bush%20Foreign%20Policy/id-73efbb63762c409f88ee7116da2a3e66',
#                'MentionSourceName': 'ap.org',
#                'MentionTimeDate': 20150218230000,
#                'MentionType': 1,
#                'SentenceID': 12},
#               {'ActionCharOffset': 2829,
#                'Actor1CharOffset': 2841,
#                'Actor2CharOffset': 2808,
#                'Confidence': 10,
#                'EventTimeDate': 20150218230000,
#                'Extras': '',
#                'InRawText': 0,
#                'MentionDocLen': 5037,
#                'MentionDocOriginalLanguage': 'eng',
#                'MentionDocTone': -1.18063754427391,
#                'MentionDocTranslationInfo': '',
#                'MentionIdentifier': 'http://www.stamfordadvocate.com/news/politics/article/GOP-s-Bush-noting-difference-with-former-6087040.php',
#                'MentionSourceName': 'stamfordadvocate.com',
#                'MentionTimeDate': 20150218230000,
#                'MentionType': 1,
#                'SentenceID': 13},
#               {'ActionCharOffset': 2805,
#                'Actor1CharOffset': 2817,
#                'Actor2CharOffset': 2784,
#                'Confidence': 10,
#                'EventTimeDate': 20150218230000,
#                'Extras': '',
#                'InRawText': 0,
#                'MentionDocLen': 5670,
#                'MentionDocOriginalLanguage': 'eng',
#                'MentionDocTone': -1.15424973767051,
#                'MentionDocTranslationInfo': '',
#                'MentionIdentifier': 'http://www.sacbee.com/news/politics-government/article10580870.html',
#                'MentionSourceName': 'sacbee.com',
#                'MentionTimeDate': 20150218230000,
#                'MentionType': 1,
#                'SentenceID': 13},
#               {'ActionCharOffset': 2821,
#                'Actor1CharOffset': 2833,
#                'Actor2CharOffset': 2800,
#                'Confidence': 10,
#                'EventTimeDate': 20150218230000,
#                'Extras': '',
#                'InRawText': 0,
#                'MentionDocLen': 5143,
#                'MentionDocOriginalLanguage': 'eng',
#                'MentionDocTone': -1.05263157894737,
#                'MentionDocTranslationInfo': '',
#                'MentionIdentifier': 'http://hosted2.ap.org/APDEFAULT/3d281c11a96b4ad082fe88aa0db04305/Article_2015-02-18-US--GOP%202016-Bush%20Foreign%20Policy/id-73efbb63762c409f88ee7116da2a3e66',
#                'MentionSourceName': 'ap.org',
#                'MentionTimeDate': 20150218230000,
#                'MentionType': 1,
#                'SentenceID': 12},
#               {'ActionCharOffset': 2626,
#                'Actor1CharOffset': 2638,
#                'Actor2CharOffset': 2605,
#                'Confidence': 10,
#                'EventTimeDate': 20150218230000,
#                'Extras': '',
#                'InRawText': 0,
#                'MentionDocLen': 4789,
#                'MentionDocOriginalLanguage': 'eng',
#                'MentionDocTone': -1.35467980295567,
#                'MentionDocTranslationInfo': '',
#                'MentionIdentifier': 'http://www.newser.com/article/73efbb63762c409f88ee7116da2a3e66/2016-prospect-jeb-bush-says-us-must-tighten-the-noose-in-fight-with-islamic-state-militants.html',
#                'MentionSourceName': 'newser.com',
#                'MentionTimeDate': 20150218231500,
#                'MentionType': 1,
#                'SentenceID': 13},
#               {'ActionCharOffset': 2826,
#                'Actor1CharOffset': 2838,
#                'Actor2CharOffset': 2805,
#                'Confidence': 10,
#                'EventTimeDate': 20150218230000,
#                'Extras': '',
#                'InRawText': 0,
#                'MentionDocLen': 5030,
#                'MentionDocOriginalLanguage': 'eng',
#                'MentionDocTone': -1.18203309692671,
#                'MentionDocTranslationInfo': '',
#                'MentionIdentifier': 'http://www.bostonherald.com/news_opinion/national/2015/02/jeb_bush_us_must_tighten_the_noose_in_fight_against_is',
#                'MentionSourceName': 'bostonherald.com',
#                'MentionTimeDate': 20150218231500,
#                'MentionType': 1,
#                'SentenceID': 13},
#               {'ActionCharOffset': 3807,
#                'Actor1CharOffset': 3819,
#                'Actor2CharOffset': 3786,
#                'Confidence': 10,
#                'EventTimeDate': 20150218230000,
#                'Extras': '',
#                'InRawText': 0,
#                'MentionDocLen': 6078,
#                'MentionDocOriginalLanguage': 'eng',
#                'MentionDocTone': -1.1881188118811898,
#                'MentionDocTranslationInfo': '',
#                'MentionIdentifier': 'http://www.roanoke.com/news/politics/wire/jeb-bush-us-must-tighten-the-noose-in-fight-against/article_8fed123f-8f49-50f3-9e4b-02537c642a1a.html',
#                'MentionSourceName': 'roanoke.com',
#                'MentionTimeDate': 20150218233000,
#                'MentionType': 1,
#                'SentenceID': 15},
#               {'ActionCharOffset': 2829,
#                'Actor1CharOffset': 2841,
#                'Actor2CharOffset': 2808,
#                'Confidence': 10,
#                'EventTimeDate': 20150218230000,
#                'Extras': '',
#                'InRawText': 0,
#                'MentionDocLen': 5037,
#                'MentionDocOriginalLanguage': 'eng',
#                'MentionDocTone': -1.18063754427391,
#                'MentionDocTranslationInfo': '',
#                'MentionIdentifier': 'http://billingsgazette.com/news/national/elections/jeb-bush-us-must-tighten-the-noose-in-fight-against/article_6921dfee-c4f2-574d-a744-1eff28b50650.html',
#                'MentionSourceName': 'billingsgazette.com',
#                'MentionTimeDate': 20150218233000,
#                'MentionType': 1,
#                'SentenceID': 13},
#               {'ActionCharOffset': 3807,
#                'Actor1CharOffset': 3819,
#                'Actor2CharOffset': 3786,
#                'Confidence': 10,
#                'EventTimeDate': 20150218230000,
#                'Extras': '',
#                'InRawText': 0,
#                'MentionDocLen': 6080,
#                'MentionDocOriginalLanguage': 'eng',
#                'MentionDocTone': -1.1881188118811898,
#                'MentionDocTranslationInfo': '',
#                'MentionIdentifier': 'http://kdhnews.com/news/politics/jeb-bush-us-must-tighten-the-noose-in-fight-against/article_698e5ee2-3aa6-5569-b957-be21d01c17b8.html',
#                'MentionSourceName': 'kdhnews.com',
#                'MentionTimeDate': 20150218233000,
#                'MentionType': 1,
#                'SentenceID': 15},
#               {'ActionCharOffset': 2829,
#                'Actor1CharOffset': 2841,
#                'Actor2CharOffset': 2808,
#                'Confidence': 10,
#                'EventTimeDate': 20150218230000,
#                'Extras': '',
#                'InRawText': 0,
#                'MentionDocLen': 5037,
#                'MentionDocOriginalLanguage': 'eng',
#                'MentionDocTone': -1.18063754427391,
#                'MentionDocTranslationInfo': '',
#                'MentionIdentifier': 'http://tucson.com/news/national/govt-and-politics/jeb-bush-us-must-tighten-the-noose-in-fight-against/article_30436acd-682d-588a-9443-9d5471e117ff.html',
#                'MentionSourceName': 'tucson.com',
#                'MentionTimeDate': 20150218233000,
#                'MentionType': 1,
#                'SentenceID': 13},
#               {'ActionCharOffset': 2829,
#                'Actor1CharOffset': 2841,
#                'Actor2CharOffset': 2808,
#                'Confidence': 10,
#                'EventTimeDate': 20150218230000,
#                'Extras': '',
#                'InRawText': 0,
#                'MentionDocLen': 5055,
#                'MentionDocOriginalLanguage': 'eng',
#                'MentionDocTone': -1.18063754427391,
#                'MentionDocTranslationInfo': '',
#                'MentionIdentifier': 'http://cnsnews.com/news/article/jeb-bush-us-must-tighten-noose-fight-against',
#                'MentionSourceName': 'cnsnews.com',
#                'MentionTimeDate': 20150218233000,
#                'MentionType': 1,
#                'SentenceID': 13},
#               {'ActionCharOffset': 2829,
#                'Actor1CharOffset': 2841,
#                'Actor2CharOffset': 2808,
#                'Confidence': 10,
#                'EventTimeDate': 20150218230000,
#                'Extras': '',
#                'InRawText': 0,
#                'MentionDocLen': 5037,
#                'MentionDocOriginalLanguage': 'eng',
#                'MentionDocTone': -1.18063754427391,
#                'MentionDocTranslationInfo': '',
#                'MentionIdentifier': 'http://theworldlink.com/news/national/govt-and-politics/jeb-bush-us-must-tighten-the-noose-in-fight-against/article_67d086e6-a8cb-57fa-875b-87294ba29c9d.html',
#                'MentionSourceName': 'theworldlink.com',
#                'MentionTimeDate': 20150218233000,
#                'MentionType': 1,
#                'SentenceID': 13},
#               {'ActionCharOffset': 2829,
#                'Actor1CharOffset': 2841,
#                'Actor2CharOffset': 2808,
#                'Confidence': 10,
#                'EventTimeDate': 20150218230000,
#                'Extras': '',
#                'InRawText': 0,
#                'MentionDocLen': 5055,
#                'MentionDocOriginalLanguage': 'eng',
#                'MentionDocTone': -1.18063754427391,
#                'MentionDocTranslationInfo': '',
#                'MentionIdentifier': 'http://www.newsradioklbj.com/news/politics/top-political-news/jeb-bush-us-must-tighten-noose-fight-against',
#                'MentionSourceName': 'newsradioklbj.com',
#                'MentionTimeDate': 20150218233000,
#                'MentionType': 1,
#                'SentenceID': 13},
#               {'ActionCharOffset': 3623,
#                'Actor1CharOffset': 3635,
#                'Actor2CharOffset': 3602,
#                'Confidence': 10,
#                'EventTimeDate': 20150218230000,
#                'Extras': '',
#                'InRawText': 0,
#                'MentionDocLen': 5813,
#                'MentionDocOriginalLanguage': 'eng',
#                'MentionDocTone': -1.0351966873706,
#                'MentionDocTranslationInfo': '',
#                'MentionIdentifier': 'http://www.timesfreepress.com/news/breakingnews/story/2015/feb/18/jeb-bush-us-must-tighten-noose-fight-against-islamic-state/289019/',
#                'MentionSourceName': 'timesfreepress.com',
#                'MentionTimeDate': 20150218234500,
#                'MentionType': 1,
#                'SentenceID': 15},
#               {'ActionCharOffset': 2829,
#                'Actor1CharOffset': 2841,
#                'Actor2CharOffset': 2808,
#                'Confidence': 10,
#                'EventTimeDate': 20150218230000,
#                'Extras': '',
#                'InRawText': 0,
#                'MentionDocLen': 5037,
#                'MentionDocOriginalLanguage': 'eng',
#                'MentionDocTone': -1.18063754427391,
#                'MentionDocTranslationInfo': '',
#                'MentionIdentifier': 'http://chippewa.com/news/national/govt-and-politics/jeb-bush-us-must-tighten-the-noose-in-fight-against/article_ab725300-f530-54fb-82e1-59e6ac649714.html',
#                'MentionSourceName': 'chippewa.com',
#                'MentionTimeDate': 20150218234500,
#                'MentionType': 1,
#                'SentenceID': 13},
#               {'ActionCharOffset': 4311,
#                'Actor1CharOffset': 4323,
#                'Actor2CharOffset': 4290,
#                'Confidence': 10,
#                'EventTimeDate': 20150218230000,
#                'Extras': '',
#                'InRawText': 0,
#                'MentionDocLen': 6596,
#                'MentionDocOriginalLanguage': 'eng',
#                'MentionDocTone': -1.1872146118721498,
#                'MentionDocTranslationInfo': '',
#                'MentionIdentifier': 'http://www.moultonadvertiser.com/news/national/article_1e2d2e49-5064-54b4-a6a8-79c46d0c793b.html',
#                'MentionSourceName': 'moultonadvertiser.com',
#                'MentionTimeDate': 20150218234500,
#                'MentionType': 1,
#                'SentenceID': 16},
#               {'ActionCharOffset': 2829,
#                'Actor1CharOffset': 2841,
#                'Actor2CharOffset': 2808,
#                'Confidence': 10,
#                'EventTimeDate': 20150218230000,
#                'Extras': '',
#                'InRawText': 0,
#                'MentionDocLen': 5037,
#                'MentionDocOriginalLanguage': 'eng',
#                'MentionDocTone': -1.18063754427391,
#                'MentionDocTranslationInfo': '',
#                'MentionIdentifier': 'http://thetandd.com/news/national/government-and-politics/jeb-bush-us-must-tighten-the-noose-in-fight-against/article_15f1a266-25bd-5bae-ac2c-d6a1e1c94aef.html',
#                'MentionSourceName': 'thetandd.com',
#                'MentionTimeDate': 20150218234500,
#                'MentionType': 1,
#                'SentenceID': 13},
#               {'ActionCharOffset': 2829,
#                'Actor1CharOffset': 2841,
#                'Actor2CharOffset': 2808,
#                'Confidence': 10,
#                'EventTimeDate': 20150218230000,
#                'Extras': '',
#                'InRawText': 0,
#                'MentionDocLen': 5037,
#                'MentionDocOriginalLanguage': 'eng',
#                'MentionDocTone': -1.18063754427391,
#                'MentionDocTranslationInfo': '',
#                'MentionIdentifier': 'http://dailyjournalonline.com/news/politics/jeb-bush-us-must-tighten-the-noose-in-fight-against/article_87a9b278-ac52-5ccf-b721-c14170801407.html',
#                'MentionSourceName': 'dailyjournalonline.com',
#                'MentionTimeDate': 20150218234500,
#                'MentionType': 1,
#                'SentenceID': 13}],
#  'MonthYear': 201402,
#  'NumArticles': 4,
#  'NumMentions': 4,
#  'NumSources': 3,
#  'QuadClass': 1,
#  'SOURCEURL': 'http://hosted2.ap.org/APDEFAULT/89ae8247abe8493fae24405546e9a1aa/Article_2015-02-18-US--GOP%202016-Bush%20Foreign%20Policy/id-73efbb63762c409f88ee7116da2a3e66',
#  'SQLDATE': 20140218,
#  'Year': 2014,
#  '_id': 410412374}

# %%
print(len(mb_gdelt_main.find_one(filter={'_id': 410412374})['MENTIONS']), batch.shape[0])
# Out:
# 18 18

# %% [markdown]
# For the entire GDELT Mentions:

# %%
# %%time
pandas_to_mongo_mentions = gdelt_mentions_processed[['GLOBALEVENTID']].copy()
pandas_to_mongo_mentions['MENTIONS'] = gdelt_mentions_processed.drop('GLOBALEVENTID', axis=1).to_dict('records')
pandas_to_mongo_mentions = pandas_to_mongo_mentions.groupby('GLOBALEVENTID')['MENTIONS'].apply(list)
pandas_to_mongo_mentions = pandas_to_mongo_mentions.reset_index()
# Out:
# Wall time: 12.3 s

# %%
pandas_to_mongo_mentions.head()
# Out:
#    GLOBALEVENTID                                           MENTIONS
# 0      403685556  [{'EventTimeDate': 20150119000000, 'MentionTim...
# 1      403686013  [{'EventTimeDate': 20150119000000, 'MentionTim...
# 2      403688003  [{'EventTimeDate': 20150119000000, 'MentionTim...
# 3      403688601  [{'EventTimeDate': 20150119001500, 'MentionTim...
# 4      403692727  [{'EventTimeDate': 20150119003000, 'MentionTim...

# %%
pandas_to_mongo_mentions.shape[0]
# Out:
# 42614

# %%
# %%time
for _, row in tqdm(pandas_to_mongo_mentions.iterrows(), position=0, total=pandas_to_mongo_mentions.shape[0]):
    _ = mb_gdelt_main.update_many({'GLOBALEVENTID': row['GLOBALEVENTID']},
                                 {'$push': {'MENTIONS': {'$each': row['MENTIONS']}}},
                                 upsert=True)
# Out:
#  38%|████████████████████████████▋                                               | 16065/42614 [08:29<14:01, 31.53it/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <timed exec> in <module>()
#
# c:\anaconda\lib\site-packages\pymongo\collection.py in update_many(self, filter, update, upsert, array_filters, bypass_document_validation, collation, session)
#    1063                 bypass_doc_val=bypass_document_validation,
#    1064                 collation=collation, array_filters=array_filters,
# -> 1065                 session=session),
#    1066             write_concern.acknowledged)
#    1067
#
# c:\anaconda\lib\site-packages\pymongo\collection.py in _update_retryable(self, criteria, document, upsert, check_keys, multi, manipulate, write_concern, op_id, ordered, bypass_doc_val, collation, array_filters, session)
#     849         return self.__database.client._retryable_write(
#     850             (write_concern or self.write_concern).acknowledged and not multi,
# --> 851             _update, session)
#     852
#     853     def replace_one(self, filter, replacement, upsert=False,
#
# c:\anaconda\lib\site-packages\pymongo\mongo_client.py in _retryable_write(self, retryable, func, session)
#    1241         """Internal retryable write helper."""
#    1242         with self._tmp_session(session) as s:
# -> 1243             return self._retry_with_session(retryable, func, s, None)
#    1244
#    1245     def __reset_server(self, address):
#
# c:\anaconda\lib\site-packages\pymongo\mongo_client.py in _retry_with_session(self, retryable, func, session, bulk)
#    1194                         # Reset the transaction id and retry the operation.
#    1195                         session._retry_transaction_id()
# -> 1196                     return func(session, sock_info, retryable)
#    1197             except ServerSelectionTimeoutError:
#    1198                 if is_retrying():
#
# c:\anaconda\lib\site-packages\pymongo\collection.py in _update(session, sock_info, retryable_write)
#     845                 bypass_doc_val=bypass_doc_val, collation=collation,
#     846                 array_filters=array_filters, session=session,
# --> 847                 retryable_write=retryable_write)
#     848
#     849         return self.__database.client._retryable_write(
#
# c:\anaconda\lib\site-packages\pymongo\collection.py in _update(self, sock_info, criteria, document, upsert, check_keys, multi, manipulate, write_concern, op_id, ordered, bypass_doc_val, collation, array_filters, session, retryable_write)
#     815             session=session,
#     816             client=self.__database.client,
# --> 817             retryable_write=retryable_write).copy()
#     818         _check_write_command_response(result)
#     819         # Add the updatedExisting field for compatibility.
#
# c:\anaconda\lib\site-packages\pymongo\pool.py in command(self, dbname, spec, slave_ok, read_preference, codec_options, check, allowable_errors, check_keys, read_concern, write_concern, parse_write_concern_error, collation, session, client, retryable_write, publish_events)
#     582         # Catch socket.error, KeyboardInterrupt, etc. and close ourselves.
#     583         except BaseException as error:
# --> 584             self._raise_connection_failure(error)
#     585
#     586     def send_message(self, message, max_doc_size):
#
# c:\anaconda\lib\site-packages\pymongo\pool.py in _raise_connection_failure(self, error)
#     743             _raise_connection_failure(self.address, error)
#     744         else:
# --> 745             raise error
#     746
#     747     def __eq__(self, other):
#
# c:\anaconda\lib\site-packages\pymongo\pool.py in command(self, dbname, spec, slave_ok, read_preference, codec_options, check, allowable_errors, check_keys, read_concern, write_concern, parse_write_concern_error, collation, session, client, retryable_write, publish_events)
#     577                            compression_ctx=self.compression_context,
#     578                            use_op_msg=self.op_msg_enabled,
# --> 579                            unacknowledged=unacknowledged)
#     580         except OperationFailure:
#     581             raise
#
# c:\anaconda\lib\site-packages\pymongo\network.py in command(sock, dbname, spec, slave_ok, is_mongos, read_preference, codec_options, session, client, check, allowable_errors, address, check_keys, listeners, max_bson_size, read_concern, parse_write_concern_error, collation, compression_ctx, use_op_msg, unacknowledged)
#     139             response_doc = {"ok": 1}
#     140         else:
# --> 141             reply = receive_message(sock, request_id)
#     142             unpacked_docs = reply.unpack_response(codec_options=codec_options)
#     143
#
# c:\anaconda\lib\site-packages\pymongo\network.py in receive_message(sock, request_id, max_message_size)
#     171     # Ignore the response's request id.
#     172     length, _, response_to, op_code = _UNPACK_HEADER(
# --> 173         _receive_data_on_socket(sock, 16))
#     174     # No request_id for exhaust cursor "getMore".
#     175     if request_id is not None:
#
# c:\anaconda\lib\site-packages\pymongo\network.py in _receive_data_on_socket(sock, length)
#     230         while bytes_read < length:
#     231             try:
# --> 232                 chunk_length = sock.recv_into(mv[bytes_read:])
#     233             except (IOError, OSError) as exc:
#     234                 if _errno_from_exception(exc) == errno.EINTR:
#
# KeyboardInterrupt:

# %% [markdown]
# ## 2.2. GDELT Queries with MongoDB
#
# - [More complex aggregations in MongoDB](https://stackoverflow.com/questions/43448389/mongo-aggregate-sum-of-values-in-a-list-of-dictionaries-for-all-documents)
# - [Aggregate across multiple fields simultaneously](https://stackoverflow.com/questions/25843255/mongodb-aggregate-count-on-multiple-fields-simultaneously)
#
# **1. Afficher le nombre d’articles/évènements qu’il y a eu pour chaque triplet (jour, pays de l’évènement, langue de l’article).**

# %%
query_mb_events_triplet = [
    {'$unwind': '$MENTIONS'},
    {'$group': {'_id': {'date':'$SQLDATE',
                        'event_country': '$ActionGeo_CountryCode',
                        'article_language': '$MENTIONS.MentionDocOriginalLanguage'},
                'NbEvents': {'$sum': 1}}
    }
]
pprint(query_mb_events_triplet)
# Out:
# [{'$unwind': '$MENTIONS'},
#  {'$group': {'NbEvents': {'$sum': 1},
#              '_id': {'article_language': '$MENTIONS.MentionDocOriginalLanguage',
#                      'date': '$SQLDATE',
#                      'event_country': '$ActionGeo_CountryCode'}}}]

# %%
result_events_triplet = list(mb_gdelt_main.aggregate(query_mb_events_triplet))

# %%
len(result_events_triplet)
# Out:
# 354

# %%
sorted(result_events_triplet, key=lambda x: x['NbEvents'], reverse=True)[:20]
# Out:
# [{'NbEvents': 23539, '_id': {'article_language': 'eng'}},
#  {'NbEvents': 3535, '_id': {'article_language': 'spa'}},
#  {'NbEvents': 1709,
#   '_id': {'article_language': 'eng', 'date': 20150218, 'event_country': 'LY'}},
#  {'NbEvents': 1276, '_id': {'article_language': 'ara'}},
#  {'NbEvents': 1087,
#   '_id': {'article_language': 'eng', 'date': 20150218, 'event_country': 'US'}},
#  {'NbEvents': 1019, '_id': {'article_language': 'fra'}},
#  {'NbEvents': 487, '_id': {'article_language': 'rus'}},
#  {'NbEvents': 420, '_id': {'article_language': 'por'}},
#  {'NbEvents': 400,
#   '_id': {'article_language': 'eng', 'date': 20150218, 'event_country': 'YM'}},
#  {'NbEvents': 361,
#   '_id': {'article_language': 'eng', 'date': 20150218, 'event_country': 'AG'}},
#  {'NbEvents': 355, '_id': {'article_language': 'deu'}},
#  {'NbEvents': 278,
#   '_id': {'article_language': 'eng', 'date': 20150218, 'event_country': 'EG'}},
#  {'NbEvents': 254,
#   '_id': {'article_language': 'eng', 'date': 20150218, 'event_country': 'IZ'}},
#  {'NbEvents': 217,
#   '_id': {'article_language': 'eng', 'date': 20150218, 'event_country': 'IT'}},
#  {'NbEvents': 176, '_id': {'article_language': 'ell'}},
#  {'NbEvents': 175, '_id': {'article_language': 'ita'}},
#  {'NbEvents': 162,
#   '_id': {'article_language': 'eng', 'date': 20140218, 'event_country': 'IZ'}},
#  {'NbEvents': 151,
#   '_id': {'article_language': 'eng', 'date': 20150218, 'event_country': 'CA'}},
#  {'NbEvents': 130,
#   '_id': {'article_language': 'eng', 'date': 20150218, 'event_country': 'ML'}},
#  {'NbEvents': 117,
#   '_id': {'article_language': 'eng', 'date': 20150218, 'event_country': 'SY'}}]

# %% [markdown]
# Pour l'instant c'est normal que la requête ne marche pas à 100% car on a des :
#
#     {'NbEvents': 23539, '_id': {'article_language': 'eng'}
#
# au lieu de
#
#     {'NbEvents': 1087, _id': {'article_language': 'eng', 'date': 20150218, 'event_country': 'US'}}
#
# Parce que je n'ai pas mis à jour encore l'ensemble des tables. Faudra utiliser Spark.

# %% [markdown]
# **2. Pour un pays donné en paramètre, affichez les évènements qui y ont eu place triées par le nombre de mentions (tri décroissant); permettez une agrégation par jour/mois/année.**

# %% [markdown]
# **3. Pour une source de données passée en paramètre (gkg.SourceCommonName) affichez les thèmes, personnes, lieux dont les articles de cette sources parlent ainsi que le le nombre d’articles et le ton moyen des articles (pour chaque thème/personne/lieu); permettez une agrégation par jour/mois/année**

# %% [markdown]
# **4. Dresser la cartographie des relations entre les pays d’après le ton des articles : pour chaque paire (pays1, pays2), calculer le nombre d’article, le ton moyen (aggrégations sur Année/Mois/Jour, filtrage par pays ou carré de coordonnées).**
